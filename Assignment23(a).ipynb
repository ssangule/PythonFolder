# %%
# Q1 to Q13 => Q5,Q7,Q9,Q10 (x)(nhi aaya)

# %%
# Write a function reverse() that inputs a number and return the reverse of that number, for example if input is 1293, function should return 3921. 


num = int(input())

temp = num
rev = 0

while temp > 0:
    last_digit = temp % 10
    rev = rev * 10 + last_digit
    temp = temp // 10
print(rev)

# %%
# Using the function reverse() in previous program, make a function isPalindrome() that inputs a number and checks whether it is a palindrome number. A number is palindrome number if it remains same after reversing its digits, for example 949, 82328 are palindrome

def palindrome(num):
    temp = num
    rev = 0
    while temp > 0:
        last_digit = temp % 10
        rev = rev * 10 + last_digit
        temp = temp // 10
    if rev == num: print("Palindrome")
    else: print("Not Palindrome")
    
num = int(input())
palindrome(num)

# %%
# Q3. Write a function isprime() which takes a number and returns 1 if the number is prime and 0 otherwise. 

import math
def prime(num):
    flag = False
    if num < 2: flag = False
    elif num == 2 or num == 3: flag = True
    elif num % 2 == 0 or num % 3 == 0 : flag = False
    else:
        for i in range(5, int(math.sqrt(num))+1):
            if num % i == 0:
                flag = False
                break
        else: flag = True
    if flag: print(1)
    else: print(0)
        
num = int(input())
prime(num)

# %%
# Q.4 Write a function that inputs two numbers and prints all prime numbers between those numbers.  

import math

def prime(number):
    for num in range(1,number+1):
        if num < 2: pass
        elif num == 2 or num == 3: lst.append(num)
        elif num % 2 == 0 or num % 3 == 0 : pass
        else:
            for i in range(5, int(math.sqrt(num))+1):
                if num % i == 0:
                    break
            else: lst.append(num)
    print(lst)
        
number = int(input())
lst = []
prime(number)

# %%
# Write a program to raise a floating point number to an integer power(eg. an where a is floating point number and n is an integer value.)  
# Note: do not use ** and pow built function of python for this purpose 

def power(a,b):
    if b == 0: return 1
    if b == 1: return a
    else: return (a * power(a,b-1))

a = float(input())
b = int(input())
print(power(a,b))

# %%
# Write a program to implement these formulae of permutations and combinations. 

# Number of permutations of n objects taken r at a time is:  
# p(n,r) = n! / (n-r)! 

# Number of combinations of n objects taken r at a time is: 
# c(n,r) = n! / ( r! * (n-r)! ) 
# or c(n,r) = p(n,r) / r! 

def fac(n):
    f = 1
    for i in range(1,n+1):
        f = f*i
    return f

def permutation(n,r):
    a = fac(n)
    b = fac(n-r)
    return a//b

def combination(n,r):
    a = fac(n)
    b = fac(r)
    c = fac(n-r)
    return a//(b*c)

val = int(input("What Do you want to calculate: 1. Permutations 2. Combinations"))
if val==1:
    n, r = map(int,input().split())
    res = permutation(n,r)
    print(res)
elif val==2:
    n, r = map(int,input().split())
    res = combination(n,r);
    print(res)

# %%
# Write a program to find out the prime factors of a number. Some examples of prime factors are –  

# Prime factors of 56 – 2, 2, 2, 7 
# Prime factors of 98 – 2, 7, 7 
# Prime factors of 121 – 11, 11 

import math


def prime(num):
    flag = False
    if num < 2: flag = False
    elif num == 2 or num == 3: flag = True
    elif num % 2 == 0 or num % 3 == 0 : flag = False
    else:
        for i in range(5, int(math.sqrt(num))+1):
            if num % i == 0:
                flag = False
                break
        else: flag = True
    if flag: return 1
    else: return 0
    
    
num = int(input())
lst = []
for i in range(2, int(math.sqrt(num))+1):
    if num % i == 0:
        a = prime(i)
        if a == 1: lst.append(i)
print(lst)

# %%
# Q12. Write a function cubesum() that accepts an integer and returns the sum of the cubes of individual digits of that number.  

def cubesum(num):
    sum = 0
    for i in num:
        sum = sum + (int(i)**3)
    print(sum)        

num = input()
cubesum(num)

# %%
# Q13. Write a function prodDigits() that inputs a number and return the prduct of digits of that number. 

def prodigits(num):
    product = 1
    for i in num:
        product = product * (int(i))
    print(product)        

num = input()
prodigits(num)
